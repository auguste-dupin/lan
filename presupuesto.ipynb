# %%
# Matplotlib forms basis for visualization in Python
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# We will use the Seaborn library
import seaborn as sns
import plotly.express as px

sns.set()

# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'

# %%
raw_df = pd.read_excel('./data/presupuesto/gastos.xlsx', index_col='Departamento')

# %%
def clean(raw_df):
    raw_df = raw_df.copy()
    df = raw_df.T

    index = []
    cols = []
    for col in df.columns:
        name = col.split(' - ')[1]
        cols.append(name)
    df.columns = cols

    df.index = pd.to_datetime(df.index).to_period('M')

    return df

df = clean(raw_df)
df
# Out:
#          MINISTERIO DE EDUCACIÓN  \
# 2004-01               767.431394
# 2004-02              1283.158893
# 2004-03               761.393822
# 2004-04               977.228918
# 2004-05              1045.296284
# ...                          ...
# 2022-01             13046.961683
# 2022-02             17651.401885
# 2022-03             17074.320966
# 2022-04             17934.264403
# 2022-05             14903.137916
#
#          ADMINISTRACION DE DEUDA PUBLICA Y ACTIVOS FINANCIEROS  \
# 2004-01                                        2957.048138
# 2004-02                                         363.081423
# 2004-03                                        1495.604579
# 2004-04                                        1423.852384
# 2004-05                                           0.000000
# ...                                                    ...
# 2022-01                                       32591.870267
# 2022-02                                       13004.240149
# 2022-03                                       15142.799726
# 2022-04                                        4350.896030
# 2022-05                                       12673.823221
#
#          MINISTERIO DE SALUD PÚBLICA Y ASISTENCIA SOCIAL  \
# 2004-01                                       441.501377
# 2004-02                                      1114.511859
# 2004-03                                       620.576890
# 2004-04                                       783.188067
# 2004-05                                       669.940108
# ...                                                  ...
# 2022-01                                      6580.286207
# 2022-02                                      9408.916033
# 2022-03                                     11446.616584
# 2022-04                                      8734.230454
# 2022-05                                     10343.685462
#
#          ADMINISTACION DE OBLIGACIONES DEL TESORO NACIONAL  \
# 2004-01                                        1522.415598
# 2004-02                                        1392.365401
# 2004-03                                        1722.824601
# 2004-04                                        1550.421226
# 2004-05                                        1847.898740
# ...                                                    ...
# 2022-01                                        6298.078271
# 2022-02                                        7497.604893
# 2022-03                                        7533.673448
# 2022-04                                       10362.093483
# 2022-05                                        8453.850259
#
#          PRESIDENCIA DE LA REPUBLICA  MINISTERIO DE INTERIOR Y POLICIA  \
# 2004-01                   362.220320                        652.003699
# 2004-02                  1928.116568                        331.174289
# 2004-03                   752.496154                       1198.357116
# 2004-04                  2835.405955                        795.622783
# 2004-05                  1667.379770                        886.941661
# ...                              ...                               ...
# 2022-01                  4996.649184                       3393.012747
# 2022-02                  5846.971695                       3671.233224
# 2022-03                  6055.164319                       3771.267868
# 2022-04                  6010.677870                       3875.570851
# 2022-05                  7728.793639                       3803.278987
#
#          MINISTERIO DE OBRAS PUBLICAS Y COMUNICACIONES  MINISTERIO DE DEFENSA  \
# 2004-01                                      61.212292             379.487534
# 2004-02                                     121.288006             401.215430
# 2004-03                                     211.422295             460.689713
# 2004-04                                     268.587660             497.840682
# 2004-05                                     291.520428             506.063817
# ...                                                ...                    ...
# 2022-01                                     771.161549            2502.888647
# 2022-02                                    2292.269967            2923.434915
# 2022-03                                    2644.279395            3069.225242
# 2022-04                                    2106.287016            3414.650089
# 2022-05                                    2695.438154            3245.183382
#
#          MINISTERIO DE HACIENDA  \
# 2004-01              117.150522
# 2004-02              161.325115
# 2004-03              186.615808
# 2004-04              248.194468
# 2004-05              173.627554
# ...                         ...
# 2022-01             1280.822756
# 2022-02             1439.923821
# 2022-03             1555.993971
# 2022-04             1536.917768
# 2022-05             1451.717698
#
#          MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TECNOLOGIA  ...  \
# 2004-01                                         115.394787      ...
# 2004-02                                         119.969762      ...
# 2004-03                                         122.484633      ...
# 2004-04                                         124.737051      ...
# 2004-05                                         122.558712      ...
# ...                                                    ...      ...
# 2022-01                                         831.437209      ...
# 2022-02                                        1208.195773      ...
# 2022-03                                        1250.827179      ...
# 2022-04                                        1128.365798      ...
# 2022-05                                        1230.368981      ...
#
#          SENADO DE LA REPUBLICA  CÁMARA DE CUENTAS  TRIBUNAL CONSTITUCIONAL  \
# 2004-01                     NaN          10.833333                      NaN
# 2004-02                     NaN          10.833333                      NaN
# 2004-03                     NaN          10.833334                      NaN
# 2004-04                     NaN          10.833333                      NaN
# 2004-05                     NaN          10.833333                      NaN
# ...                         ...                ...                      ...
# 2022-01              219.648243          94.593731               131.280973
# 2022-02              219.648243         135.993184               131.280979
# 2022-03              219.648243         123.221389               131.280975
# 2022-04              219.648243         124.489479               131.280975
# 2022-05              219.648243         124.286452               131.280975
#
#          MINISTERIO DE ENERGIA Y MINAS  MINISTERIO DE ADMINISTRACION PUBLICA  \
# 2004-01                            NaN                                   NaN
# 2004-02                            NaN                                   NaN
# 2004-03                            NaN                                   NaN
# 2004-04                            NaN                                   NaN
# 2004-05                            NaN                                   NaN
# ...                                ...                                   ...
# 2022-01                      71.162298                             77.850770
# 2022-02                     165.664163                             92.504293
# 2022-03                     143.217349                            103.550673
# 2022-04                     142.459411                            115.412960
# 2022-05                     122.749756                            138.375064
#
#          MINISTERIO DE LA MUJER  MINISTERIO DE LA JUVENTUD  \
# 2004-01                6.421497                   5.144062
# 2004-02                8.601356                   6.156662
# 2004-03               15.084596                  17.294818
# 2004-04               13.509925                   6.629613
# 2004-05                9.652545                   8.065232
# ...                         ...                        ...
# 2022-01               68.138999                  14.598395
# 2022-02               68.141596                  23.825447
# 2022-03               86.237894                  83.142541
# 2022-04              111.322752                  34.844243
# 2022-05               81.487180                  40.230639
#
#          MINISTERIO DE LA VIVIENDA, HABITAT Y EDIFICACIONES (MIVHED)  \
# 2004-01                                                NaN
# 2004-02                                                NaN
# 2004-03                                                NaN
# 2004-04                                                NaN
# 2004-05                                                NaN
# ...                                                    ...
# 2022-01                                         320.050740
# 2022-02                                         794.982172
# 2022-03                                         775.618666
# 2022-04                                         487.147903
# 2022-05                                        3062.896201
#
#          TRIBUNAL SUPERIOR ELECTORAL (TSE)  DEFENSOR DEL PUEBLO
# 2004-01                                NaN                  NaN
# 2004-02                                NaN                  NaN
# 2004-03                                NaN                  NaN
# 2004-04                                NaN                  NaN
# 2004-05                                NaN                  NaN
# ...                                    ...                  ...
# 2022-01                          75.156794            15.525817
# 2022-02                          75.156794            17.803155
# 2022-03                          75.156794            20.156249
# 2022-04                          75.156794            25.394027
# 2022-05                          75.156793            26.463086
#
# [221 rows x 34 columns]

# %%
# Melt
def melt(df):
    df = df.copy()
    cols = df.columns
    df.reset_index(inplace=True)
    df.rename(columns={'index':'Fecha'}, inplace=True)
    
    df = pd.melt(
        df,
        id_vars = ['Fecha'],
        value_vars = cols,
        var_name='Organizacion',
        value_name='Valor'
    )

    df.set_index('Fecha', drop=True, inplace=True)

    return df
df = melt(df)
df
# Out:
#                     Organizacion        Valor
# Fecha
# 2004-01  MINISTERIO DE EDUCACIÓN   767.431394
# 2004-02  MINISTERIO DE EDUCACIÓN  1283.158893
# 2004-03  MINISTERIO DE EDUCACIÓN   761.393822
# 2004-04  MINISTERIO DE EDUCACIÓN   977.228918
# 2004-05  MINISTERIO DE EDUCACIÓN  1045.296284
# ...                          ...          ...
# 2022-01      DEFENSOR DEL PUEBLO    15.525817
# 2022-02      DEFENSOR DEL PUEBLO    17.803155
# 2022-03      DEFENSOR DEL PUEBLO    20.156249
# 2022-04      DEFENSOR DEL PUEBLO    25.394027
# 2022-05      DEFENSOR DEL PUEBLO    26.463086
#
# [7514 rows x 2 columns]

# %%
fig = px.area(df, x=df.index.strftime("%Y-%m"), y='Valor', color='Organizacion').show()

# %%
def market_share(df):
    df = df.copy()

    for i in df.index:
        total = df.loc[i].sum()['Valor']
        df.loc[i,'MS'] = df.loc[i]['Valor'] / total

    return df
df = market_share(df)
df
# Out:
#                     Organizacion        Valor        MS
# Fecha
# 2004-01  MINISTERIO DE EDUCACIÓN   767.431394  0.093265
# 2004-02  MINISTERIO DE EDUCACIÓN  1283.158893  0.153802
# 2004-03  MINISTERIO DE EDUCACIÓN   761.393822  0.085321
# 2004-04  MINISTERIO DE EDUCACIÓN   977.228918  0.086344
# 2004-05  MINISTERIO DE EDUCACIÓN  1045.296284  0.123328
# ...                          ...          ...       ...
# 2022-01      DEFENSOR DEL PUEBLO    15.525817  0.000198
# 2022-02      DEFENSOR DEL PUEBLO    17.803155  0.000242
# 2022-03      DEFENSOR DEL PUEBLO    20.156249  0.000257
# 2022-04      DEFENSOR DEL PUEBLO    25.394027  0.000366
# 2022-05      DEFENSOR DEL PUEBLO    26.463086  0.000340
#
# [7514 rows x 3 columns]

# %%
def top_orgs(df, n=10):
    df = df.copy()

    max_date = max(df.index)
    max_df = df.groupby(by=['Organizacion']).sum()['Valor']
    max_df = max_df.sort_values(ascending=False)
    max_df = max_df.reset_index()
    top = max_df[:n]
    orgs = list(top['Organizacion'])

    top_orgs = df[df['Organizacion'].isin(orgs)]
    bottom_orgs = df[~df['Organizacion'].isin(orgs)]
    bottom = bottom_orgs.reset_index()
    bottom = bottom_orgs.groupby(by=['Fecha']).sum()
    bottom['Organizacion'] = 'Demas'
    df = pd.concat([top_orgs,bottom])

    # df.sort_values(by=['Valor'])
    
    return df

top = top_orgs(df)
top
# Out:
#                     Organizacion         Valor        MS
# Fecha
# 2004-01  MINISTERIO DE EDUCACIÓN    767.431394  0.093265
# 2004-02  MINISTERIO DE EDUCACIÓN   1283.158893  0.153802
# 2004-03  MINISTERIO DE EDUCACIÓN    761.393822  0.085321
# 2004-04  MINISTERIO DE EDUCACIÓN    977.228918  0.086344
# 2004-05  MINISTERIO DE EDUCACIÓN   1045.296284  0.123328
# ...                          ...           ...       ...
# 2022-01                    Demas   6225.114216  0.079282
# 2022-02                    Demas   8516.886542  0.115937
# 2022-03                    Demas   8913.732570  0.113612
# 2022-04                    Demas   9896.857449  0.142707
# 2022-05                    Demas  11398.660467  0.146272
#
# [2431 rows x 3 columns]

# %%
def roll(df, n=6):
    df = df.copy()
    # df = df.sort_index()
    all_df = pd.DataFrame()

    for org in df['Organizacion'].unique():
        temp = df[df['Organizacion'] == org]
        temp = temp[['Valor','MS']].rolling(6).mean()
        temp['Organizacion'] = org
        all_df = pd.concat([all_df, temp], ignore_index=False)
        # print(org)
        # print(temp)
        # print('#################')
    all_df.dropna(inplace=True)
    return all_df

rolled = roll(top, 6)
rolled
# Out:
#                 Valor        MS             Organizacion
# Fecha
# 2004-06    951.625141  0.107717  MINISTERIO DE EDUCACIÓN
# 2004-07    993.416862  0.110238  MINISTERIO DE EDUCACIÓN
# 2004-08    908.932407  0.100423  MINISTERIO DE EDUCACIÓN
# 2004-09    921.248204  0.103156  MINISTERIO DE EDUCACIÓN
# 2004-10    881.183186  0.106849  MINISTERIO DE EDUCACIÓN
# ...               ...       ...                      ...
# 2022-01  12189.866056  0.120696                    Demas
# 2022-02  12137.462929  0.118466                    Demas
# 2022-03  12095.010412  0.118240                    Demas
# 2022-04  12164.357447  0.118804                    Demas
# 2022-05  11769.275161  0.121904                    Demas
#
# [2376 rows x 3 columns]

# %%
def area_chart(df):
    df = df.copy().dropna()
    fig = px.area(df, x=df.index.strftime("%Y-%m"), y='MS', color='Organizacion', title='Gasto como % por Organizacion')
    fig.update_layout(legend_traceorder="reversed",height=800)
    fig.show()
area_chart(rolled)

# %%
def bar_chart(df):
    df = df.copy().dropna()
    fig = px.area(df, x=df.index.strftime("%Y-%m"), y='Valor', color='Organizacion', title='Gasto como % por Organizacion')
    fig.update_layout(legend_traceorder="reversed",height=800)
    fig.show()
bar_chart(rolled)

# %%
def line_MS(df):
    fig = px.line(df,x=df.index.strftime('%Y-%m'),y='MS',color='Organizacion',title='Gasto como % por Organizacion')
    fig.update_layout(legend_traceorder="reversed",height=800)
    fig.show()
line_MS(rolled)

# %%
top = df[df['Organizacion'].isin(cols)]
bottom = df[~df['Organizacion'].isin(cols)]
# Out:
#                                               Organizacion       Valor  \
# Fecha
# 2004-01  MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TEC...  115.394787
# 2004-02  MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TEC...  119.969762
# 2004-03  MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TEC...  122.484633
# 2004-04  MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TEC...  124.737051
# 2004-05  MINISTERIO DE EDUCACION SUPERIOR CIENCIA Y TEC...  122.558712
# ...                                                    ...         ...
# 2022-01                                DEFENSOR DEL PUEBLO   15.525817
# 2022-02                                DEFENSOR DEL PUEBLO   17.803155
# 2022-03                                DEFENSOR DEL PUEBLO   20.156249
# 2022-04                                DEFENSOR DEL PUEBLO   25.394027
# 2022-05                                DEFENSOR DEL PUEBLO   26.463086
#
#                MS
# Fecha
# 2004-01  0.014024
# 2004-02  0.014380
# 2004-03  0.013726
# 2004-04  0.011021
# 2004-05  0.014460
# ...           ...
# 2022-01  0.000198
# 2022-02  0.000242
# 2022-03  0.000257
# 2022-04  0.000366
# 2022-05  0.000340
#
# [5304 rows x 3 columns]
